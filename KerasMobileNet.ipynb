# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Activation,Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf.h5
# 17225924/17225924 [==============================] - 4s 0us/step

# %%
def prepare_image(file):
    img_path = 'C:/Users/joelt/Desktop/Jupyter/prac 2/MobileNet-samples/'
    img = image.load_img(img_path + file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return tf.keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
from IPython.display import Image
Image(filename='C:/Users/joelt/Desktop/Jupyter/prac 2/MobileNet-samples/2.JPG', width=300,height=200)

# %%
preprocessed_image = prepare_image('2.JPG')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# 1/1 [==============================] - 0s 32ms/step
# [[('n07745940', 'strawberry', 0.99999344),
#   ('n07749582', 'lemon', 1.2442104e-06),
#   ('n07747607', 'orange', 8.6024215e-07),
#   ('n07753275', 'pineapple', 8.278211e-07),
#   ('n07768694', 'pomegranate', 6.2610394e-07)]]
